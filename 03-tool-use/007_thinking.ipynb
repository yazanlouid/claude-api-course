# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-5"

# %%
# Helper functions
from anthropic.types import Message

# Magic string to trigger redacted thinking
thinking_test_str = "ANTHROPIC_MAGIC_STRING_TRIGGER_REDACTED_THINKING_46C9A13E193C177646C7398A98432ECCCE4C1253D5E2D82641AC0E52CC2876CB"


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(
    messages,
    system=None,
    effort=None,
    stop_sequences=[],
    tools=None,
    thinking=False,
    # thinking_budget=1024
):
    params = {
        "model": model,
        "max_tokens": 4000,
        "messages": messages,
        "stop_sequences": stop_sequences,  
    }

    if thinking:
        params["thinking"] = {"type": "adaptive"}

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    if effort:
        params["output_config"] = {"effort": effort}

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
messages = []

add_user_message(messages, "A farmer has 17 sheep. All but 9 die. How many are left? Then explain the classic version of this riddle and why people get it wrong.")

chat(messages, thinking=True, effort="max")
# Out:
# Message(id='msg_011CePw7pvVGy371CAn25YgX', container=None, content=[ThinkingBlock(signature='...', thinking='', type='thinking'), TextBlock(citations=None, text='**Answer: 9 sheep are left.**\n\nThe phrase "all but 9 die" means "all except 9 die" — so 9 survive. The number 17 is irrelevant to solving the puzzle; it\'s there to distract you.\n\n## The Classic Riddle\n\nThis is a well-known lateral-thinking riddle, often phrased as:\n\n> "A farmer had 17 sheep. All but nine died. How many are left?"\n\nIt\'s designed to trip people up by making them think a math calculation is needed, when really it\'s a language/parsing puzzle.\n\n## Why People Get It Wrong\n\nMost people blurt out **8** (doing 17 − 9) instead of the correct answer, **9**. Here\'s why:\n\n1. **Pattern matching:** The sentence structure mimics a typical school word problem ("farmer has X animals, Y die, how many are left?"), which almost always requires subtraction. Your brain recognizes the *shape* of a subtraction problem and runs with it before actually parsing the words.\n\n2. **Misreading "but" as a connector, not "except":** In casual reading, "but" often just links clauses. People skim past its actual meaning here — "except" — and treat 17 and 9 as two numbers to be combined mathematically.\n\n3. **Fast, automatic thinking (System 1):** Riddles like this exploit quick, intuitive judgment rather than careful, deliberate reading. Since the setup *sounds* like a math problem, your brain jumps to the "obvious" operation instead of slowing down to check the grammar.\n\n4. **Assumption that all numbers must be used:** School math conditions people to believe every number given in a problem must be part of the calculation. So when 17 and 9 both appear, the instinct is to combine them — even though the riddle only needs one of them.\n\nThe trick works precisely because it *looks* like arithmetic but is actually a comprehension test. Once you slow down and read "all **but** 9" as "all **except** 9," the answer becomes obvious.', type='text')], model='claude-sonnet-5', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='global', input_tokens=52, output_tokens=1786, output_tokens_details=OutputTokensDetails(thinking_tokens=1146), server_tool_use=None, service_tier='standard'))
