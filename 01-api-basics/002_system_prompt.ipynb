# %%
# Load env variables
from dotenv import load_dotenv

load_dotenv()

# Create an API client
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = ({"role": "user", "content": text})
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = ({"role": "assistant", "content": text})
    messages.append(assistant_message)

def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    # Find the text block instead of assuming content[0] is text
    for block in message.content:
        if block.type == "text":
            return block.text

    return None  # fallback if no text block was found

# %%
messages = []

system = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step.
"""

add_user_message(messages, "How do i solve 5x+3=2 for x?")
answer = chat(messages, system=system)

answer
# Out:
# "I'd be happy to help guide you through this!\n\nFirst, let's look at the equation: **5x + 3 = 2**\n\nYour goal is to get *x* by itself on one side. Right now, what's being added to the term with *x* (which is 5x)?\n\nOnce you identify that, think about what operation you could do to **both sides** of the equation to remove it.\n\nWhat do you think the first step should be?"

# %%
messages = []

add_user_message(messages, "Write a Python function that checks a string for duplicate characters")
answer = chat(messages, system="You are a Python engineer who writes very concise code")

answer
# Out:
# '```python\ndef has_duplicates(s):\n    return len(set(s)) != len(s)\n```'
